# %% [markdown]
# # HW_4_Pandas_Heroes_of_Pymoli

# %%
#Player Count
#total number of players
#Name--> Series --> first_column --> lood at the shape--> rows X columns
import pandas as pd
import numpy as np
from pandas import Series, DataFrame
pd_4 = pd.read_json(("purchase_data.json"))
#from pandas import Series, DataFrame
pd_4
# Out:
#      Age                 Gender  Item ID  \
# 0     38                   Male      165
# 1     21                   Male      119
# 2     34                   Male      174
# 3     21                   Male       92
# 4     23                   Male       63
# 5     20                   Male       10
# 6     20                   Male      153
# 7     29                 Female      169
# 8     25                   Male      118
# 9     31                   Male       99
# 10    24                   Male       57
# 11    20                   Male       47
# 12    30                   Male       81
# 13    23                   Male       77
# 14    40                   Male       44
# 15    21                   Male       96
# 16    22                 Female      123
# 17    22                 Female       59
# 18    28                   Male       91
# 19    31                   Male      177
# 20    24                   Male       78
# 21    15                   Male        3
# ...

# %%
pd_4.describe()
# Out:
#               Age     Item ID       Price
# count  780.000000  780.000000  780.000000
# mean    22.729487   91.293590    2.931192
# std      6.930604   52.707537    1.115780
# min      7.000000    0.000000    1.030000
# 25%     19.000000   44.000000    1.960000
# 50%     22.000000   91.000000    2.880000
# 75%     25.000000  135.000000    3.910000
# max     45.000000  183.000000    4.950000

# %%
pd_4.columns = [c.replace(' ', '_') for c in pd_4.columns]

# %%
pd_4.columns
# Out:
# Index(['Age', 'Gender', 'Item_ID', 'Item_Name', 'Price', 'SN'], dtype='object')

# %%
pd_4[pd_4.Item_ID == 174]
# Out:
#      Age  Gender  Item_ID        Item_Name  Price           SN
# 2     34    Male      174  Primitive Blade   2.46  Assastnya25
# 106   37  Female      174  Primitive Blade   2.46   Chadossa56
# 377   37    Male      174  Primitive Blade   2.46   Aduephos78
# 584   21  Female      174  Primitive Blade   2.46       Aina43
# 715   15    Male      174  Primitive Blade   2.46        Ila44

# %%
pd_4[pd_4.Age == 10]
# Out:
#      Age  Gender  Item_ID                           Item_Name  Price  \
# 436   10    Male      131                                Fury   4.82
# 656   10  Female       63                      Stormfury Mace   1.27
# 730   10  Female      148  Warmonger, Gift of Suffering's End   3.96
# 735   10    Male       16                     Restored Bauble   3.11
#
#                SN
# 436  Ethrusuard41
# 656    Ilaststa70
# 730  Hiadanurin36
# 735  Ethrusuard41

# %%
print('Number of players',len(pd_4.SN.unique()))
# Out:
# Number of players 573

# %%
pd_4.columns = [c.replace(' ', "_") for c in pd_4.columns]

# %%
pd_4.columns
# Out:
# Index(['Age', 'Gender', 'Item_ID', 'Item_Name', 'Price', 'SN'], dtype='object')

# %%
unique_players = (len(pd_4.SN.unique()))

# %%
unique_players
# Out:
# 573

# %%
players = pd.DataFrame({'Players_count': 573}, columns = ['Players_count'], index = [0] )

# %% [markdown]
# # players_count_DONE

# %%
players
# Out:
#    Players_count
# 0            573

# %% [markdown]
# # player_count_DONE_BELOW

# %%
players = pd.DataFrame({'Players_count': unique_players}, columns = ['Players_count'], index = [0] )
players
# Out:
#    Players_count
# 0            573

# %%
pd_4.columns = [c.replace(' ', '_') for c in pd_4.columns]

# %%
pd_4.columns
# Out:
# Index(['Age', 'Gender', 'Item_ID', 'Item_Name', 'Price', 'SN'], dtype='object')

# %%
pd_4
# Out:
#      Age                 Gender  Item_ID  \
# 0     38                   Male      165
# 1     21                   Male      119
# 2     34                   Male      174
# 3     21                   Male       92
# 4     23                   Male       63
# 5     20                   Male       10
# 6     20                   Male      153
# 7     29                 Female      169
# 8     25                   Male      118
# 9     31                   Male       99
# 10    24                   Male       57
# 11    20                   Male       47
# 12    30                   Male       81
# 13    23                   Male       77
# 14    40                   Male       44
# 15    21                   Male       96
# 16    22                 Female      123
# 17    22                 Female       59
# 18    28                   Male       91
# 19    31                   Male      177
# 20    24                   Male       78
# 21    15                   Male        3
# ...

# %% [markdown]
# # Age Demographics_DONE

# %%
pd_4_10 = pd_4[pd_4.Age < 10]# LESS THAN 10 YEARS
pd_4_10
# Out:
#      Age  Gender  Item_ID                                 Item_Name  Price  \
# 70     7  Female      158        Darkheart, Butcher of the Champion   3.56
# 121    7    Male      175                Woeful Adamantite Claymore   1.24
# 125    7  Female       10                               Sleepwalker   1.73
# 170    9    Male       71                                    Demise   4.07
# 237    7    Male      121                                  Massacre   3.42
# 260    9    Male       99      Expiration, Warscythe Of Lost Worlds   4.53
# 271    7    Male       77                Piety, Guardian of Riddles   3.68
# 289    8    Male       79                       Alpha, Oath of Zeal   2.88
# 291    7    Male       53                         Vengeance Cleaver   3.70
# 292    7    Male      121                                  Massacre   3.42
# 360    7  Female       21                                 Souleater   3.27
# ...

# %%
pd_4_10.describe()
# Out:
#              Age     Item_ID      Price
# count  28.000000   28.000000  28.000000
# mean    7.535714   82.321429   2.980714
# std     0.838082   53.684989   1.128358
# min     7.000000   10.000000   1.030000
# 25%     7.000000   37.750000   1.940000
# 50%     7.000000   77.000000   3.345000
# 75%     8.000000  121.000000   3.680000
# max     9.000000  177.000000   4.890000

# %% [markdown]
# # Demographics Age Less Than 10 (Age < 10)_ HINT

# %% [markdown]
# ## get dataFrame for each groups and then concatenate all DataFrames to get a new dataFrame (add  + all 4 dataframes to make new dataFrame )

# %%
pd_4_10.describe()
# Out:
#              Age     Item_ID      Price
# count  28.000000   28.000000  28.000000
# mean    7.535714   82.321429   2.980714
# std     0.838082   53.684989   1.128358
# min     7.000000   10.000000   1.030000
# 25%     7.000000   37.750000   1.940000
# 50%     7.000000   77.000000   3.345000
# 75%     8.000000  121.000000   3.680000
# max     9.000000  177.000000   4.890000

# %%
pd_4_10.Price.sum()
# Out:
# 83.46000000000001

# %% [markdown]
# # Demographics Age Less Than 10 (Age < 10)

# %% [markdown]
# ## include the normalize in the dataFrame (below)

# %%
#making a dataFrame of Age < 10


cols = ['Purchase_count', 'mean', 'Total_Purchase']
df_4_less_10 = pd.DataFrame({'Purchase_count': 128, 'mean': 7.53, 'Total_Purchase': 83.46},
                      columns =cols, index = ['<10'])
df_4_less_10
# Out:
#      Purchase_count  mean  Total_Purchase
# <10             128  7.53           83.46

# %% [markdown]
# # Demographics Age Less Than 10 (Age < 10)

# %% [markdown]
# # Demographics  (Age >= 10 & Age <= 14)_DONE

# %%
pd_4_age_10_14 = pd_4[(pd_4.Age >= 10) & (pd_4.Age <= 14)]
pd_4_age_10_14
# Out:
#      Age                 Gender  Item_ID  \
# 22    11                 Female       11
# 24    11                   Male       65
# 46    11                   Male       17
# 68    11                   Male       38
# 117   11                   Male      160
# 137   13                 Female       20
# 145   11                   Male       71
# 149   13                   Male      175
# 152   13                   Male       17
# 184   11                   Male      170
# 195   14                   Male      160
# 201   12                   Male      137
# 216   13                 Female      116
# 276   12  Other / Non-Disclosed      128
# 344   12                   Male       66
# 358   14                   Male       87
# 361   14                   Male       39
# 404   11                 Female       46
# 436   10                   Male      131
# 451   12                   Male      163
# 511   12                   Male       70
# 513   13                   Male      159
# ...

# %%
#making a dataFrame for (Age >= 10 & Age <= 14)

cols = ['Purchase_count', 'mean', 'Total_Purchase']
df_4_10_14 = pd.DataFrame({'Purchase_count': 35, 'mean': 2.77, 'Total_Purchase': 96.95},
                      columns =cols, index = ['10-14'])
df_4_10_14
# Out:
#        Purchase_count  mean  Total_Purchase
# 10-14              35  2.77           96.95

# %%
pd_4_age_10_14.describe()
# Out:
#              Age     Item_ID      Price
# count  35.000000   35.000000  35.000000
# mean   12.171429   90.600000   2.770000
# std     1.316987   61.037211   1.103702
# min    10.000000    5.000000   1.240000
# 25%    11.000000   32.000000   1.920000
# 50%    12.000000   80.000000   2.520000
# 75%    13.000000  153.500000   3.680000
# max    14.000000  183.000000   4.820000

# %% [markdown]
# # Demographics  (Age >= 10 & Age <= 14)_DONE

# %%
pd_4_age_10_14.Price.sum()
# Out:
# 96.94999999999999

# %% [markdown]
# # Demographics Age  (Age >= 15 & Age <= 19)_DONE

# %%
#making a dataFrame for (Age >= 10 & Age <= 14)

cols = ['Purchase_count', 'mean', 'Total_Purchase']
df_4_15_19 = pd.DataFrame({'Purchase_count': 133, 'mean': '$2.91', 'Total_Purchase': '$386.42'},
                      columns =cols, index = ['15-19'])
df_4_15_19
# Out:
#        Purchase_count   mean Total_Purchase
# 15-19             133  $2.91        $386.42

# %% [markdown]
# # Demographics Age  (Age >= 15 & Age <= 19)_DONE

# %%
pd_4_15_19 = pd_4[(pd_4.Age >= 15) & (pd_4.Age <= 19)]
pd_4_15_19.describe()
# Out:
#               Age     Item_ID       Price
# count  133.000000  133.000000  133.000000
# mean    16.631579   94.443609    2.905414
# std      1.519937   55.148891    1.121010
# min     15.000000    2.000000    1.030000
# 25%     15.000000   41.000000    1.980000
# 50%     16.000000  102.000000    2.720000
# 75%     18.000000  143.000000    3.960000
# max     19.000000  183.000000    4.950000

# %%
pd_4_15_19['Price'].sum()
# Out:
# 386.41999999999996

# %% [markdown]
# # Demographics Age Greater Than 19 ( Age > 19)_DONE

# %%
pd_4_19 = pd_4[(pd_4.Age > 19)]
pd_4_19
# Out:
#      Age                 Gender  Item_ID  \
# 0     38                   Male      165
# 1     21                   Male      119
# 2     34                   Male      174
# 3     21                   Male       92
# 4     23                   Male       63
# 5     20                   Male       10
# 6     20                   Male      153
# 7     29                 Female      169
# 8     25                   Male      118
# 9     31                   Male       99
# 10    24                   Male       57
# 11    20                   Male       47
# 12    30                   Male       81
# 13    23                   Male       77
# 14    40                   Male       44
# 15    21                   Male       96
# 16    22                 Female      123
# 17    22                 Female       59
# 18    28                   Male       91
# 19    31                   Male      177
# 20    24                   Male       78
# 25    21                   Male       63
# ...

# %%
pd_4_19.describe()
# Out:
#               Age     Item_ID       Price
# count  584.000000  584.000000  584.000000
# mean    25.479452   91.047945    2.944349
# std      5.448614   51.637884    1.116681
# min     20.000000    0.000000    1.030000
# 25%     22.000000   46.750000    1.975000
# 50%     24.000000   91.000000    2.895000
# 75%     28.000000  133.000000    3.910000
# max     45.000000  183.000000    4.950000

# %%
cols = ['Purchase_count', 'mean', 'Total_Purchase']

df_4_19_hi = pd.DataFrame({'Purchase_count': 584, 'mean': 2.94, 'Total_Purchase': 1719.50},
                      columns =cols, index = ['>19'])
df_4_19_hi
# Out:
#      Purchase_count  mean  Total_Purchase
# >19             584  2.94          1719.5

# %%
df_4_19_hi
# Out:
#      Purchase_count  mean  Total_Purchase
# >19             584  2.94          1719.5

# %% [markdown]
# # Demographics Age Greater Than 19 ( Age > 19)_DONE

# %%
pd_4_19.describe()
# Out:
#               Age     Item_ID       Price
# count  584.000000  584.000000  584.000000
# mean    25.479452   91.047945    2.944349
# std      5.448614   51.637884    1.116681
# min     20.000000    0.000000    1.030000
# 25%     22.000000   46.750000    1.975000
# 50%     24.000000   91.000000    2.895000
# 75%     28.000000  133.000000    3.910000
# max     45.000000  183.000000    4.950000

# %%
pd_4_19.Price.sum()
# Out:
# 1719.4999999999989

# %%
round(pd_4.Price.mean(),2)
# Out:
# 2.93

# %% [markdown]
# # PURCHASEING ANALYSIS (AGE)

# %%
indx = ['<10', '10-14', '15-19', '>19']
cols = ['Purchase_count', 'Average_purchase_price', 'Total_purchase_price']
df_purchas_analysis = pd.DataFrame({'Purchase_count': [128, 35, 81, 133], 'Average_purchase_price': ['$7.53', '$2.77', '$2.91', '2.94'], 'Total_purchase_price': ['$83.46', '$56.55', '$386.42', '$719.5']},
                                  columns = cols, index = indx) 
df_purchas_analysis
# Out:
#        Purchase_count Average_purchase_price Total_purchase_price
# <10               128                  $7.53               $83.46
# 10-14              35                  $2.77               $56.55
# 15-19              81                  $2.91              $386.42
# >19               133                   2.94               $719.5

# %% [markdown]
# # purshasing_analysis_DONE

# %%
purshasing_analysis = pd.DataFrame({'Unique_Items':179, 'Average_Purchase_Price': 2.93, 'Total_Number_of_Purchases':780 , 'Total_Revenue': 2286.33},columns = ['Unique_Items',  'Average_Purchase_Price','Total Number_of_Purchases', 'Total_Revenue'], index = [0])

# %%
purshasing_analysis
# Out:
#    Unique_Items  Average_Purchase_Price Total Number_of_Purchases  \
# 0           179                    2.93                       NaN
#
#    Total_Revenue
# 0        2286.33

# %%
pd_4.columns = [c.replace(' ', '_') for c in pd_4.columns ]
pd_4.columns
# Out:
# Index(['Age', 'Gender', 'Item_ID', 'Item_Name', 'Price', 'SN'], dtype='object')

# %%
pd_4[pd_4.Item_ID == 158]
# Out:
#      Age  Gender  Item_ID                           Item_Name  Price  \
# 70     7  Female      158  Darkheart, Butcher of the Champion   3.56
# 147   22    Male      158  Darkheart, Butcher of the Champion   3.56
# 163   23    Male      158  Darkheart, Butcher of the Champion   3.56
# 385   25    Male      158  Darkheart, Butcher of the Champion   3.56
# 477   25    Male      158  Darkheart, Butcher of the Champion   3.56
# 610    7    Male      158  Darkheart, Butcher of the Champion   3.56
# 768   21    Male      158  Darkheart, Butcher of the Champion   3.56
#
#                 SN
# 70      Eosurdru76
# 147     Chadanto83
# 163        Tyida79
# 385      Haerith37
# 477  Frichistast39
# 610     Lassjask63
# 768   Chamucosda93

# %% [markdown]
# # MAKING A DATAfRAME_AGE_DEMOGRAPHIC

# %%
indx = ['<10', '10-14', '15-19', '>19']
cols = ['Percent_of_Players', 'Total_Count']
df_age_demo = pd.DataFrame({'Percent_of_Players':[14.55, 4, 15.11, 66.36], 'Total_Count': [128, 35, 133, 584]},
                          columns = cols, index = indx)

# %%
df_age_demo
# Out:
#        Percent_of_Players  Total_Count
# <10                 14.55          128
# 10-14                4.00           35
# 15-19               15.11          133
# >19                 66.36          584

# %% [markdown]
# # DATAfRAME_AGE_DEMOGRAPHIC

# %%
#Purchasing Analysis (Total)
total = pd_4.Price.sum()
print('Total revenue =',round(total,2))
# Out:
# Total revenue = 2286.33

# %%
len(pd_4.Price) # there are 780 purchases
# Out:
# 780

# %%
#Number of Unique Items--> 5th columns in the dataFrame-->  Total = df['MyColumn'].sum() print (Total) 319
#Average Purchase Price --> total_price /number of purchase
#Total Number of Purchases--> 5th columnn --> count
#Total Revenue--> sum the last column

# %%
#Number of Unique Items--> 5th columns in the dataFrame
unique_items = pd_4.Item_Name.unique()
len(unique_items)
# Out:
# 179

# %%
print('There are',len(unique_items),'unique items')
# Out:
# There are 179 unique items

# %%
#Gender Demographics

#The below each broken by gender (M or F) --> 3rd column -- groupby--> gender
#Purchase Count -->how many bought by M,  how many bought by F --> group by
#Average Purchase Price --> male , female
#Total Purchase Value --> total purchase of male, and total purchase of Female--> groupby gender, purchase
#Normalized Totals

# %% [markdown]
# ### Gender Demographics (EXPLAIN)
# pd_4.groupby(''

# %%
pd_4.groupby('Gender').agg(['count', 'max', 'min', 'mean'])
# Out:
#                         Age                    Item_ID                       \
#                       count max min       mean   count  max min        mean
# Gender
# Female                  136  40   7  22.558824     136  182   6   88.110294
# Male                    633  45   7  22.685624     633  183   0   91.571880
# Other / Non-Disclosed    11  34  12  27.363636      11  183  29  114.636364
#
#                       Price
#                       count   max   min      mean
# Gender
# Female                  136  4.95  1.03  2.815515
# Male                    633  4.95  1.03  2.950521
# Other / Non-Disclosed    11  4.32  1.88  3.249091

# %%
Gender_Demographics = pd.DataFrame({'Male_Players':633 , 'Female_Players': 136, 'Other_Non_Disclosed': 11, 'Percentage_Male': 81.15, 'Percentage_Female': 17.43 , 'Percentage_Other_Non_Disclosed': 1.41},
                                   columns = ['Male_Players','Female_Players','Other_Non_Disclosed', 'Percentage_Male', 'Percentage_Female', 'Percentage_Other_Non_Disclosed'], index = [0])

# %%
Gender_Demographics
# Out:
#    Male_Players  Female_Players  Other_Non_Disclosed  Percentage_Male  \
# 0           633             136                   11            81.15
#
#    Percentage_Female  Percentage_Other_Non_Disclosed
# 0              17.43                            1.41

# %%
pd_gender_demo = pd.DataFrame({'Percent_of_Players':[81.15, 17.43, 1.41], 'Total_Count':[633, 133, 11]},
                             columns = ['Percent_of_Players','Total_Count'], index = ['Male', 'Female', 'Others'])

# %% [markdown]
# # Gender_Demographics_Done

# %%
pd_gender_demo
# Out:
#         Percent_of_Players  Total_Count
# Male                 81.15          633
# Female               17.43          133
# Others                1.41           11

# %% [markdown]
# # Gender_Demographics_Done

# %% [markdown]
# # Gender_Demographics_Done

# %%
pd_4.groupby(['Gender', 'Price']).agg(['count', 'max', 'min', 'mean'])
# Out:
#                               Age                    Item_ID
#                             count max min       mean   count  max  min    mean
# Gender                Price
# Female                1.03      4  37  18  28.000000       4   95   95   95.00
#                       1.06      1  23  23  23.000000       1   74   74   74.00
#                       1.14      1  22  22  22.000000       1  123  123  123.00
#                       1.20      2  25  20  22.500000       2    6    6    6.00
#                       1.24      1  37  37  37.000000       1  175  175  175.00
#                       1.27      1  10  10  10.000000       1   63   63   63.00
#                       1.28      1  17  17  17.000000       1   86   86   86.00
#                       1.35      3  22  16  19.333333       3   33   33   33.00
#                       1.36      3  25  25  25.000000       3  104   92   96.00
#                       1.45      1  39  39  39.000000       1  161  161  161.00
# ...

# %%
pd_4.groupby(['Gender', 'Item_Name']).agg(['count', 'max', 'min', 'mean'])
# Out:
#                                                                  Age          \
#                                                                count max min
# Gender                Item_Name
# Female                Alpha                                        2  29  23
#                       Alpha, Oath of Zeal                          2  30  22
#                       Alpha, Reach of Ending Hope                  1  24  24
#                       Amnesia                                      2  33  31
#                       Apocalyptic Battlescythe                     2  35  20
#                       Arcane Gem                                   1  22  22
#                       Betrayal, Whisper of Grieving Widows         2  27  19
#                       Betrayer                                     1  24  24
#                       Blade of the Grave                           1  20  20
#                       Blazefury, Protector of Delusions            1  18  18
# ...

# %%
pd.get_option('display.max_rows')
pd.set_option('display.max_rows', None)

# %%
pd_4.groupby('Gender').agg(['count'])
# Out:
#                         Age Item_ID Item_Name Price    SN
#                       count   count     count count count
# Gender
# Female                  136     136       136   136   136
# Male                    633     633       633   633   633
# Other / Non-Disclosed    11      11        11    11    11

# %%
pd_4.groupby(['Gender', 'Item_ID', 'Age']).Age.agg(['count'])
# Out:
#                                    count
# Gender                Item_ID Age
# Female                6       20       1
#                               25       1
#                       8       21       1
#                       10      7        1
#                       11      7        1
#                               11       1
#                               20       1
#                       12      23       1
#                       13      20       1
#                               21       1
#                               22       1
#                       18      13       1
#                               25       1
#                       20      13       1
#                       21      7        1
#                       22      31       1
#                               33       1
#                       26      13       1
#                       27      17       1
#                       30      23       1
#                       31      27       1
# ...

# %%
pd_4.set_index(['Gender', 'Item_ID', 'Age'], drop=False)
# Out:
#                                    Age                 Gender  Item_ID  \
# Gender                Item_ID Age
# Male                  165     38    38                   Male      165
#                       119     21    21                   Male      119
#                       174     34    34                   Male      174
#                       92      21    21                   Male       92
#                       63      23    23                   Male       63
#                       10      20    20                   Male       10
#                       153     20    20                   Male      153
# Female                169     29    29                 Female      169
# Male                  118     25    25                   Male      118
#                       99      31    31                   Male       99
#                       57      24    24                   Male       57
#                       47      20    20                   Male       47
# ...

# %%
pd_4.set_index(['Gender','Age', 'Item_ID'], drop=True)
# Out:
#                                                                       Item_Name  \
# Gender                Age Item_ID
# Male                  38  165                       Bone Crushing Silver Skewer
#                       21  119         Stormbringer, Dark Blade of Ending Misery
#                       34  174                                   Primitive Blade
#                       21  92                                       Final Critic
#                       23  63                                     Stormfury Mace
#                       20  10                                        Sleepwalker
#                           153                                   Mercenary Sabre
# Female                29  169            Interrogator, Blood Blade of the Queen
# Male                  25  118                  Ghost Reaver, Longsword of Magic
#                       31  99               Expiration, Warscythe Of Lost Worlds
# ...

# %%
pd_4_Female = pd_4[pd_4.Gender == 'Female']

# %%
(pd_4_Female).describe()
# Out:
#               Age     Item_ID       Price
# count  136.000000  136.000000  136.000000
# mean    22.558824   88.110294    2.815515
# std      7.419459   50.502317    1.151027
# min      7.000000    6.000000    1.030000
# 25%     18.000000   45.750000    1.827500
# 50%     22.000000   89.500000    2.615000
# 75%     25.000000  123.250000    3.750000
# max     40.000000  182.000000    4.950000

# %%
pd_4_male = pd_4[pd_4.Gender == 'Male']
pd_4_male['Price']
# Out:
# 0      3.37
# 1      2.32
# 2      2.46
# 3      1.36
# 4      1.27
# 5      1.73
# 6      4.57
# 8      2.77
# 9      4.53
# 10     3.81
# 11     1.55
# 12     4.06
# 13     3.68
# 14     2.46
# 15     4.77
# 18     3.71
# 19     4.89
# 20     2.33
# 21     1.79
# 23     2.36
# 24     1.96
# 25     1.27
# 26     3.90
# 27     2.29
# 28     4.23
# 31     1.93
# 32     4.32
# 33     1.67
# 34     1.55
# 36     2.46
# 37     3.62
# 38     1.03
# 39     1.27
# 40     4.51
# 42     1.03
# 43     2.49
# 44     2.17
# 45     1.91
# 46     3.47
# 47     3.27
# 48     3.74
# 49     1.85
# 51     3.32
# 52     3.37
# 53     2.67
# 55     3.82
# 56     2.07
# 57     4.14
# 59     3.40
# 60     1.28
# 61     2.35
# 63     3.04
# 64     2.22
# 65     4.67
# 66     1.49
# 67     3.51
# 68     2.82
# 69     4.51
# 71     2.17
# 72     2.11
# 73     1.21
# 74     3.14
# 75     2.07
# 76     3.73
# 77     2.20
# 78     2.77
# 79     2.86
# 81     1.24
# 82     4.75
# 84     4.51
# 86     3.15
# ...

# %%
pd_4_male['Price'].sum()
# Out:
# 1867.6799999999985

# %% [markdown]
# ### Purchasing Analysis (Gender)  'Normalized_tbl_m':???, 'Normalized_tbl_f':??? Done_Done_Done
# #Purchase Count
# #Average Purchase Price
# #Total Purchase Value
# #Normalized Totals

# %%
cols = ['PurchaseCount_m','PurchaseCount_f','Average Purchase Price_m', 'Average Purchase Price_f','Total Purchase Value_m','Total Purchase Value_f']
Purchase_Analysis_gender = pd.DataFrame({'PurchaseCount_m':633, 'PurchaseCount_f':133,'Average Purchase Price_m':2.95, 'Average Purchase Price_f':2.82, 'Total Purchase Value_m':1867.68, 'Total Purchase Value_f':382.91}
                                         ,columns = cols, index = [0])
Purchase_Analysis_gender
# Out:
#    PurchaseCount_m  PurchaseCount_f  Average Purchase Price_m  \
# 0              633              133                      2.95
#
#    Average Purchase Price_f  Total Purchase Value_m  Total Purchase Value_f
# 0                      2.82                 1867.68                  382.91

# %%
pd_4.groupby()

# %%
#Purchase Count -->how many bought by M,  how many bought by F --> group by
pd_4.groupby( ['Gender']).Price.agg(['count', 'sum', 'mean'])
# Out:
#                        count      sum      mean
# Gender
# Female                   136   382.91  2.815515
# Male                     633  1867.68  2.950521
# Other / Non-Disclosed     11    35.74  3.249091

# %%
#Most Popular Items

#Identify the 5 most popular items by purchase count, then list (in a table):

#Item ID
#Item Name
#Purchase Count
#Item Price
#Total Purchase Value

# %%
#Identify the 5 most popular items by purchase count, then list (in a table):
#use groupby item_name --> 
#use sort method     df.sort('Bytes', ascending=False).head(10)
pd_4.sort_values('Item_Name', ascending=False).head(10)
#pd_4.groupby(['Gender','Price']).Item_Name.count()
# Out:
#      Age  Gender  Item_ID                        Item_Name  Price  \
# 270   29    Male      114               Yearning Mageblade   1.79
# 749   21    Male      114               Yearning Mageblade   1.79
# 373   23    Male      114               Yearning Mageblade   1.79
# 412   24  Female      114               Yearning Mageblade   1.79
# 430   27    Male       74                 Yearning Crusher   1.06
# 127   23  Female       74                 Yearning Crusher   1.06
# 160   25    Male      112                     Worldbreaker   3.29
# 687   15  Female      112                     Worldbreaker   3.29
# 444   20  Female      179  Wolf, Promise of the Moonwalker   1.88
# 335   16    Male      179  Wolf, Promise of the Moonwalker   1.88
#
#                 SN
# 270      Iskassa50
# 749  Frichassala85
# 373        Ermol76
# 412  Lirtossanya27
# 430     Lirtassa47
# 127      Eyircil84
# 160      Yadanun74
# 687    Crausirra42
# 444     Ithergue48
# 335     Yalaeria91

# %% [markdown]
# # (top_spender) -->how to get total of each SN (each player????????????) below to get a top spender

# %%
top_spender = pd_4.groupby(['Item_Name','SN','Item_ID']).Price.agg(['count', 'mean', 'sum'])
top_spender
# Out:
#                                                                       count  \
# Item_Name                                    SN              Item_ID
# Abyssal Shard                                Euliria52       162          1
#                                              Undast38        162          1
#                                              Wailin72        162          1
# Aetherius, Boon of the Blessed               Eustyria89      137          1
#                                              Heuralsti66     137          1
#                                              Marilsa48       137          1
#                                              Phenastya51     137          1
# Agatha                                       Ennoncil86      120          1
#                                              Eusur90         120          1
#                                              Isri49          120          1
# ...

# %% [markdown]
# # TOP SPENDER NOT SORTED

# %%
top_spender = pd_4.groupby(['SN']).Price.agg(['count', 'mean', 'sum'])
top_spender
# Out:
#                  count      mean    sum
# SN
# Adairialis76         1  2.460000   2.46
# Aduephos78           3  2.233333   6.70
# Aeduera68            3  1.933333   5.80
# Aela49               1  2.460000   2.46
# Aela59               1  1.270000   1.27
# Aelalis34            2  2.530000   5.06
# Aelin32              1  3.140000   3.14
# Aeliriam77           2  3.360000   6.72
# Aeliriarin93         1  2.040000   2.04
# Aeliru63             2  4.490000   8.98
# Aellyria80           1  4.320000   4.32
# Aellyrialis39        1  3.150000   3.15
# Aellysup38           1  3.610000   3.61
# Aelollo59            1  1.550000   1.55
# Aenarap34            1  1.650000   1.65
# Aenasu69             1  3.270000   3.27
# Aeral43              1  2.720000   2.72
# Aeral85              1  4.250000   4.25
# Aeral97              1  2.350000   2.35
# Aeri84               2  3.300000   6.60
# Aerillorin70         1  1.880000   1.88
# Aerithllora36        3  3.483333  10.45
# ...

# %% [markdown]
# # TOP SPENDER(BELOW)

# %%
top_spender.sort_values('sum', ascending=False).head()
# Out:
#              count      mean    sum
# SN
# Undirrala66      5  3.412000  17.06
# Saedue76         4  3.390000  13.56
# Mindimnya67      4  3.185000  12.74
# Haellysu29       3  4.243333  12.73
# Eoda93           3  3.860000  11.58

# %% [markdown]
# # TOP SPENDER(ABOVE)

# %%
 
pd_4.groupby(['SN']).Price.agg(['count', 'mean', 'sum'])

# %%
pd_4.sort_values('Price', ascending=False).head(25)
# Out:
#      Age  Gender  Item_ID                                 Item_Name  Price  \
# 83    25  Female       32                                   Orenmir   4.95
# 50    32  Female       32                                   Orenmir   4.95
# 657   28    Male       32                                   Orenmir   4.95
# 388   15    Male       32                                   Orenmir   4.95
# 227   20    Male       32                                   Orenmir   4.95
# 359   20    Male       32                                   Orenmir   4.95
# 532   17  Female      177  Winterthorn, Defender of Shifting Worlds   4.89
# 19    31    Male      177  Winterthorn, Defender of Shifting Worlds   4.89
# 670    7    Male      177  Winterthorn, Defender of Shifting Worlds   4.89
# 348   22    Male      177  Winterthorn, Defender of Shifting Worlds   4.89
# 471   24    Male      103                            Singed Scalpel   4.87
# ...

# %% [markdown]
# # DataFrame for Topspender(below)

# %%
indx = ['Undirrala66', 'Saedue76', 'Mindimnya67', 'Haellysu29', 'Eoda93']
df_top_spender = pd.DataFrame({'Purchase_count': [5, 4, 4, 3, 3], 'Average_purchase_count':[3.41, 3.39, 3.19, 4.24, 3.86],
                              'Total_purchase':[17.06, 13.56, 12.74, 12.73, 11.58]},
                              columns = cols, index = indx)
df_top_spender
# Out:
#              Purchase_count Average_purchase_price Total_purchase_price
# Undirrala66               5                    NaN                  NaN
# Saedue76                  4                    NaN                  NaN
# Mindimnya67               4                    NaN                  NaN
# Haellysu29                3                    NaN                  NaN
# Eoda93                    3                    NaN                  NaN

# %% [markdown]
# # DataFrame for Topspender(above)

# %%
pd_4.groupby('SN').Item_ID.agg(['count'])
# Out:
#                  count
# SN
# Adairialis76         1
# Aduephos78           3
# Aeduera68            3
# Aela49               1
# Aela59               1
# Aelalis34            2
# Aelin32              1
# Aeliriam77           2
# Aeliriarin93         1
# Aeliru63             2
# Aellyria80           1
# Aellyrialis39        1
# Aellysup38           1
# Aelollo59            1
# Aenarap34            1
# Aenasu69             1
# Aeral43              1
# Aeral85              1
# Aeral97              1
# Aeri84               2
# Aerillorin70         1
# Aerithllora36        3
# Aerithnucal56        2
# Aerithnuphos61       1
# Aerithriaphos45      1
# Aesty51              1
# Aesur96              1
# Aethe80              1
# Aethedru70           1
# Aidain51             2
# Aidaira26            1
# Aidaira48            1
# Aiduecal76           1
# Aiduesu83            1
# Ailaesuir66          1
# Aillycal84           1
# Aillyriadru65        1
# Aina42               1
# ...

# %% [markdown]
# # Most Popular Items Below_DONE_DONE_DONE

# %%
 
most_popular = pd_4.groupby(['Item_ID', 'Item_Name','Price']).Price.agg(['count', 'sum'])
most_popular
# Out:
#                                                             count    sum
# Item_ID Item_Name                                    Price
# 0       Splinter                                     1.82       1   1.82
# 1       Crucifer                                     2.28       4   9.12
# 2       Verdict                                      3.40       1   3.40
# 3       Phantomlight                                 1.79       1   1.79
# 4       Bloodlord's Fetish                           2.28       1   2.28
# 5       Putrid Fan                                   1.32       3   3.96
# 6       Rusty Skull                                  1.20       3   3.60
# 7       Thorn, Satchel of Dark Souls                 4.51       6  27.06
# 8       Purgatory, Gem of Regret                     3.91       6  23.46
# 9       Thorn, Conqueror of the Corrupted            2.04       2   4.08
# 10      Sleepwalker                                  1.73       6  10.38
# ...

# %%
most_popular.sort_values('sum', ascending=False).head(5)
# Out:
#                                           count    sum
# Item_ID Item_Name                  Price
# 34      Retribution Axe            4.14       9  37.26
# 115     Spectral Diamond Doomblade 4.25       7  29.75
# 32      Orenmir                    4.95       6  29.70
# 103     Singed Scalpel             4.87       6  29.22
# 107     Splitter, Foe Of Subtlety  3.61       8  28.88

# %% [markdown]
# # Most Popular Items above_DONE_DONE_DONE

# %%
indx = [34, 115, 32, 103, 107]
cols = ['Item_Name', 'Price', 'count', 'Total_purchase_value' ]
value_1 = ['Retribution Axe', 'Spectral Diamond Doomblade', 'Orenmir', 'Singed Scalpel', 'Splitter, Foe Of Subtlety']
value_2 = [4.14, 4.25, 4.95, 4.87, 3.61]
value_3 = [9, 7, 6, 6, 8]
value_4 = [37.26, 29.75, 29.7,29.22, 28.88]

df_most_profitable_items = pd.DataFrame({'Item_Name':value_1, 'Price': value_2, 'count': value_3, 'Total_purchase_value': value_4},
                                       columns = cols, index = indx)
df_most_profitable_items
# Out:
#                       Item_Name  Price  count  Total_purchase_value
# 34              Retribution Axe   4.14      9                 37.26
# 115  Spectral Diamond Doomblade   4.25      7                 29.75
# 32                      Orenmir   4.95      6                 29.70
# 103              Singed Scalpel   4.87      6                 29.22
# 107   Splitter, Foe Of Subtlety   3.61      8                 28.88

# %% [markdown]
# # Most Profitable Items_DONE_DONE_DONE_Below

# %%
most_profitable_items = most_popular.sort_values('sum', ascending=False).head(5)
most_profitable_items
# Out:
#                                           count    sum
# Item_ID Item_Name                  Price
# 34      Retribution Axe            4.14       9  37.26
# 115     Spectral Diamond Doomblade 4.25       7  29.75
# 32      Orenmir                    4.95       6  29.70
# 103     Singed Scalpel             4.87       6  29.22
# 107     Splitter, Foe Of Subtlety  3.61       8  28.88

# %%
indx = [34, 115, 32, 103, 107]
cols = ['Item_Name', 'Price', 'count', 'Total_purchase_value' ]
value_1 = ['Retribution Axe', 'Spectral Diamond Doomblade', 'Orenmir', 'Singed Scalpel', 'Splitter, Foe Of Subtlety']
value_2 = [4.14, 4.25, 4.95, 4.87, 3.61]
value_3 = [9, 7, 6, 6, 8]
value_4 = [37.26, 29.75, 29.7,29.22, 28.88]

df_most_profitable_items = pd.DataFrame({'Item_Name':value_1, 'Price': value_2, 'count': value_3, 'Total_purchase_value': value_4},
                                       columns = cols, index = indx)
df_most_profitable_items
# Out:
#                       Item_Name  Price  count  Total_purchase_value
# 34              Retribution Axe   4.14      9                 37.26
# 115  Spectral Diamond Doomblade   4.25      7                 29.75
# 32                      Orenmir   4.95      6                 29.70
# 103              Singed Scalpel   4.87      6                 29.22
# 107   Splitter, Foe Of Subtlety   3.61      8                 28.88

# %% [markdown]
# # Most Profitable Items_DONE_DONE_DONE_Above

# %%
# Out:
#      Age  Gender  Item_ID                                  Item_Name  Price  \
# 7     29  Female      169     Interrogator, Blood Blade of the Queen   3.32
# 16    22  Female      123                          Twilight's Carver   1.14
# 17    22  Female       59              Lightning, Etcher of the King   1.65
# 22    11  Female       11                                  Brimstone   2.52
# 29    16  Female       45                        Glinting Glass Edge   2.46
# 30    21  Female      155                  War-Forged Gold Deflector   3.73
# 35    21  Female       13                                   Serenity   1.49
# 41    19  Female      124                             Venom Claymore   2.72
# 50    32  Female       32                                    Orenmir   4.95
# 54    25  Female      101                               Final Critic   4.62
# 58    24  Female       65                  Conqueror Adamantite Mace   1.96
# ...

# %%
# Out:
#               Age     Item_ID       Price
# count  136.000000  136.000000  136.000000
# mean    22.558824   88.110294    2.815515
# std      7.419459   50.502317    1.151027
# min      7.000000    6.000000    1.030000
# 25%     18.000000   45.750000    1.827500
# 50%     22.000000   89.500000    2.615000
# 75%     25.000000  123.250000    3.750000
# max     40.000000  182.000000    4.950000

# %%
#DataFrame with hierarchical index
#data.groupby(['col1', 'col2']).mean()

# %%
pd_4.groupby(['Item_ID','Price']).mean()
# Out:
#                      Age
# Item_ID Price
# 0       1.82   30.000000
# 1       2.28   22.250000
# 2       3.40   15.000000
# 3       1.79   15.000000
# 4       2.28   20.000000
# 5       1.32   24.666667
# 6       1.20   22.333333
# 7       4.51   22.333333
# 8       3.91   21.833333
# 9       2.04   21.500000
# 10      1.73   21.333333
# 11      2.52   21.571429
# 12      4.30   21.600000
# 13      1.49   20.444444
# 14      1.59   16.600000
# 15      1.03   19.166667
# 16      3.11   17.750000
# 17      3.47   15.333333
# 18      1.77   22.571429
# 19      3.98   20.000000
# 20      1.48   18.500000
# 21      3.27   17.333333
# 22      3.57   22.333333
# 23      2.77   20.750000
# 24      2.41   22.000000
# 25      1.03   23.750000
# 26      1.88   17.250000
# 27      3.96   17.500000
# 28      3.04   23.000000
# 29      3.79   25.000000
# 30      4.15   22.800000
# 31      2.07   25.777778
# 32      4.95   23.333333
# 33      1.35   18.000000
# 34      4.14   26.000000
# ...

# %%
len(pd_4.groupby(['Item_Name']).Price.agg(['count', 'sum', 'max', 'min','mean']))
# Out:
# 179

# %%
pd_4
# Out:
#      Age                 Gender  Item_ID  \
# 0     38                   Male      165
# 1     21                   Male      119
# 2     34                   Male      174
# 3     21                   Male       92
# 4     23                   Male       63
# 5     20                   Male       10
# 6     20                   Male      153
# 7     29                 Female      169
# 8     25                   Male      118
# 9     31                   Male       99
# 10    24                   Male       57
# 11    20                   Male       47
# 12    30                   Male       81
# 13    23                   Male       77
# 14    40                   Male       44
# 15    21                   Male       96
# 16    22                 Female      123
# 17    22                 Female       59
# 18    28                   Male       91
# 19    31                   Male      177
# 20    24                   Male       78
# 21    15                   Male        3
# ...

# %%
pd_4.set_index(['Gender', 'Item_Name'], drop = False)
# Out:
#                                                                     Age  \
# Gender                Item_Name
# Male                  Bone Crushing Silver Skewer                    38
#                       Stormbringer, Dark Blade of Ending Misery      21
#                       Primitive Blade                                34
#                       Final Critic                                   21
#                       Stormfury Mace                                 23
#                       Sleepwalker                                    20
#                       Mercenary Sabre                                20
# Female                Interrogator, Blood Blade of the Queen         29
# Male                  Ghost Reaver, Longsword of Magic               25
#                       Expiration, Warscythe Of Lost Worlds           31
#                       Despair, Favor of Due Diligence                24
#                       Alpha, Reach of Ending Hope                    20
# ...

# %% [markdown]
# #  money genrated by each game  by each gender (below)_DONE_DONE_DONE

# %%
pd_4_by_group = pd_4.groupby(['Gender', 'Item_Name']).Price.agg(['sum'])
pd_4_by_group
# Out:
#                                                                       sum
# Gender                Item_Name
# Female                Alpha                                          3.12
#                       Alpha, Oath of Zeal                            5.76
#                       Alpha, Reach of Ending Hope                    1.55
#                       Amnesia                                        7.14
#                       Apocalyptic Battlescythe                       7.82
#                       Arcane Gem                                     2.23
#                       Betrayal, Whisper of Grieving Widows           4.70
#                       Betrayer                                       1.67
#                       Blade of the Grave                             1.69
#                       Blazefury, Protector of Delusions              1.50
#                       Blazeguard, Reach of Eternity                  4.00
# ...

# %% [markdown]
# pd_4_by_group.sort_values(by['Sum'], axis = 0, ascending = True)

# %%
pd_4_by_group.sort_values(by=['sum'], axis = 0, ascending = True)
# Out:
#                                                                       sum
# Gender                Item_Name
# Male                  Singed Onyx Warscythe                          1.03
# Female                Yearning Crusher                               1.06
# Male                  Yearning Crusher                               1.06
# Female                Twilight's Carver                              1.14
# Male                  Soul-Forged Steel Shortsword                   1.16
#                       Rusty Skull                                    1.20
# Female                Woeful Adamantite Claymore                     1.24
#                       Stormfury Mace                                 1.27
#                       Stormfury Lantern                              1.28
#                       Gladiator's Glaive                             1.36
#                       Devine                                         1.45
# ...

# %%
pd_4_by_group.sort_values(by=['sum'], axis = 0, ascending =False)
# Out:
#                                                                       sum
# Gender                Item_Name
# Male                  Retribution Axe                               37.26
#                       Stormcaller                                   27.72
#                       Thorn, Satchel of Dark Souls                  27.06
#                       Final Critic                                  26.64
#                       Splitter, Foe Of Subtlety                     25.27
#                       Darkheart                                     25.20
#                       Avenger                                       24.96
#                       Stormfury Longsword                           24.15
#                       Mercenary Sabre                               22.85
#                       Ritual Mace                                   22.44
#                       Arcane Gem                                    22.30
# ...

# %%
#make 2 dataFrames MALE AND FEMALE, then

# %% [markdown]
# # PURCHASEING ANALYSIS (AGE)

# %%
df_purchase = [pd_4_10, df_4_10_14, pd_4_15_19, df_4_19_hi]
df_purchase
# Out:
# [     Age  Gender  Item_ID                                 Item_Name  Price  \
#  70     7  Female      158        Darkheart, Butcher of the Champion   3.56
#  121    7    Male      175                Woeful Adamantite Claymore   1.24
#  125    7  Female       10                               Sleepwalker   1.73
#  170    9    Male       71                                    Demise   4.07
#  237    7    Male      121                                  Massacre   3.42
#  260    9    Male       99      Expiration, Warscythe Of Lost Worlds   4.53
#  271    7    Male       77                Piety, Guardian of Riddles   3.68
#  289    8    Male       79                       Alpha, Oath of Zeal   2.88
#  291    7    Male       53                         Vengeance Cleaver   3.70
#  292    7    Male      121                                  Massacre   3.42
#  360    7  Female       21                                 Souleater   3.27
# ...

# %%
df_purchase_analysis = pd.concat(df_purchase)

# %%
df_purchase_analysis
# Out:
#         Age  Gender  Item_ID                                  Item_Name  \
# 70      7.0  Female    158.0         Darkheart, Butcher of the Champion
# 121     7.0    Male    175.0                 Woeful Adamantite Claymore
# 125     7.0  Female     10.0                                Sleepwalker
# 170     9.0    Male     71.0                                     Demise
# 237     7.0    Male    121.0                                   Massacre
# 260     9.0    Male     99.0       Expiration, Warscythe Of Lost Worlds
# 271     7.0    Male     77.0                 Piety, Guardian of Riddles
# 289     8.0    Male     79.0                        Alpha, Oath of Zeal
# 291     7.0    Male     53.0                          Vengeance Cleaver
# 292     7.0    Male    121.0                                   Massacre
# 360     7.0  Female     21.0                                  Souleater
# 370     7.0    Male    151.0                                  Severance
# ...
